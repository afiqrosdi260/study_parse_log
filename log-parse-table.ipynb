# %% [markdown]
# ### Kirfan97 example code beginner parsing

# %%
import parse as pr
import pandas as pd

simple_log_data = [
    "INFO [2023-05-17 12:34:56.789] This is a simple log message",
    "ERROR [2023-05-18 01:23:45.678] An error occurred",
    "WARNING [2023-05-19 10:20:30.123] This is a warning message"
]

formatt="{type} [{date}] {message}" 

collection=[]
for line in simple_log_data:
    parsed=pr.parse(formatt,line).named
    collection.append(parsed)

pd.DataFrame(collection)
# Out:
#       type                     date                       message
# 0     INFO  2023-05-17 12:34:56.789  This is a simple log message
# 1    ERROR  2023-05-18 01:23:45.678             An error occurred
# 2  WARNING  2023-05-19 10:20:30.123     This is a warning message

# %% [markdown]
# ### Testing Parse n Pandas only

# %%
import parse 
import pandas as pd

# %%
log_format="{timestamp}  {duration} {type} {details}"

with open('C:/Users/afiqhusaini.rosdi/OneDrive - PLUS MALAYSIA BERHAD/Documents/Working_Projects/study_parse_log/LCS0001.LOG', 'r') as log_file:
    log_file_lines= log_file.readlines()

log_collection = []

for line in log_file_lines:
    parsed = parse.parse(log_format,line)
    log_collection.append(parsed.named)

# %%
df = pd.DataFrame(log_collection)
df
# Out:
#                             timestamp   duration    type  \
# 0             2024-06-28T15:32:42.672    0.00000     TFI
# 1             2024-06-28T15:32:42.680    8.07220     SEN
# 2             2024-06-28T15:32:42.726   45.15410     VDC
# 3             2024-06-28T15:33:03.763  21.03695s     APR
# 4             2024-06-28T15:33:03.763    0.07810     REC
# 5             2024-06-28T15:33:03.763    0.18260     VDC
# 6             2024-06-28T15:33:03.763    0.00000     TFI
# 7             2024-06-28T15:33:03.767    3.73560     SEN
# 8             2024-06-28T15:33:08.767   5.00071s     SEN
# 9             2024-06-28T15:33:26.251  17.48340s     RES
# 10            2024-06-28T15:33:26.254    3.18260     APR
# 11            2024-06-28T15:33:26.254    0.12820     TFI
# 12            2024-06-28T15:33:26.259    5.48120     SEN
# 13            2024-06-28T15:33:27.717   1.45763s     REM
# 14            2024-06-28T15:33:27.717    0.00000     TFI
# 15            2024-06-28T15:33:27.719    1.65430     SEN
# 16            2024-06-28T15:33:37.401   9.68267s     REC
# 17            2024-06-28T15:33:37.401    0.00000     TFI
# 18            2024-06-28T15:33:37.410    8.39830     SEN
# 19            2024-06-28T15:33:38.642   1.23219s     RES
# 20            2024-06-28T15:33:38.642    0.00000     TFI
# 21            2024-06-28T15:33:38.646    3.72120     SEN
# 22            2024-06-28T15:33:40.247   1.60108s     REM
# 23            2024-06-28T15:33:40.247    0.00000     TFI
# 24            2024-06-28T15:33:40.252    5.35940     SEN
# 25            2024-06-28T15:34:06.143  25.89064s     REC
# 26            2024-06-28T15:34:06.143    0.00000     TFI
# 27            2024-06-28T15:34:06.156   13.51320     SEN
# 28  2024-06-28T15:34:07.056 899.39230        APR  Enlist
# 29            2024-06-28T15:34:07.056    0.05300     VDC
# 30            2024-06-28T15:34:11.158   4.10230s     SEN
# 31            2024-06-28T15:34:12.292   1.13422s     RES
# 32            2024-06-28T15:34:12.293    0.88390     APR
# 33            2024-06-28T15:34:12.293    0.04050     TFI
# 34            2024-06-28T15:34:12.296    2.67140     SEN
# 35            2024-06-28T15:34:13.407   1.11115s     REM
# 36            2024-06-28T15:34:13.407    0.00000     TFI
# 37            2024-06-28T15:34:13.409    1.66430     SEN
#
#                                               details
# 0    <        ><                ><                >\n
# 1   <LTL 0><ALB 0><OTL 0><MLB 0><PSN 0><PSG 0><FSW...
# 2                                           Bounded\n
# 3   Enlist [PUTRAJAYA5555     ][470M669NWA7R1X32  ...
# 4   <QID 3B9ACA01><PSN F><PSG _><TRX S=SE V=INI E=...
# 5         Select [1:1,0][470M669NWA7R1X32  ] 0 -> 0\n
# 6    <1       ><                ><                >\n
# 7   <LTL 0><ALB 0><OTL 0><MLB 0><PSN 0><PSG 0><FSW...
# 8   <LTL 0><ALB 0><OTL 0><MLB 0><PSN 0><PSG 0><FSW...
# 9   <QID 3B9ACA01><PSN F><PSG _><TRX S=OK V=EXM E=...
# 10  Select [PUTRAJAYA5555     ][470M669NWA7R1X32  ...
# 11   <1       ><SELAMAT         ><JALAN           >\n
# 12  <LTL 1><ALB 0><OTL 0><MLB 0><PSN 0><PSG 0><FSW...
# 13  <QID 3B9ACA01><PSN F><PSG _><TRX S=OK V=EXM E=...
# 14   <        ><                ><                >\n
# 15  <LTL 0><ALB 0><OTL 0><MLB 0><PSN 0><PSG 0><FSW...
# 16  <QID 3B9ACA02><PSN F><PSG _><TRX S=SE V=INI E=...
# 17   <2       ><                ><                >\n
# 18  <LTL 0><ALB 0><OTL 0><MLB 0><PSN 0><PSG 0><FSW...
# 19  <QID 3B9ACA02><PSN F><PSG _><TRX S=OK V=EXM E=...
# 20   <2       ><SELAMAT         ><JALAN           >\n
# 21  <LTL 1><ALB 0><OTL 0><MLB 0><PSN 0><PSG 0><FSW...
# 22  <QID 3B9ACA02><PSN F><PSG _><TRX S=OK V=EXM E=...
# 23   <        ><                ><                >\n
# 24  <LTL 0><ALB 0><OTL 0><MLB 0><PSN 0><PSG 0><FSW...
# 25  <QID 3B9ACA03><PSN F><PSG _><TRX S=SE V=INI E=...
# 26   <3       ><                ><                >\n
# 27  <LTL 0><ALB 0><OTL 0><MLB 0><PSN 0><PSG 0><FSW...
# 28  [PUTRAJAYA5555     ][470M669NWA7R1X33  ] 0 -> 1\n
# 29        Select [2:2,0][470M669NWA7R1X33  ] 0 -> 0\n
# 30  <LTL 0><ALB 0><OTL 0><MLB 0><PSN 0><PSG 0><FSW...
# 31  <QID 3B9ACA03><PSN F><PSG _><TRX S=OK V=EXM E=...
# 32  Select [PUTRAJAYA5555     ][470M669NWA7R1X33  ...
# 33   <3       ><SELAMAT         ><JALAN           >\n
# 34  <LTL 1><ALB 0><OTL 0><MLB 0><PSN 0><PSG 0><FSW...
# 35  <QID 3B9ACA03><PSN F><PSG _><TRX S=OK V=EXM E=...
# 36   <        ><                ><                >\n
# 37  <LTL 0><ALB 0><OTL 0><MLB 0><PSN 0><PSG 0><FSW...

# %% [markdown]
# ### Testing using re n pandas

# %%
import pandas as pd
import parse
import re

# %%
# Define the log format with a regular expression
log_regex = re.compile(
    r'^(?P<timestamp>\S+)\s+(?P<duration>\S+)\s+(?P<type>\S+)\s+(?P<details>.+)$'
)

# Initialize a list to store parsed log entries
log_collection = []
log_file_path = 'C:/Users/afiqhusaini.rosdi/OneDrive - PLUS MALAYSIA BERHAD/Documents/Working_Projects/study_parse_log/LCS0001.LOG'

# Read the log file
with open(log_file_path, 'r') as log_file:
    log_file_lines = log_file.readlines()

# Process each log line
for line in log_file_lines:
    match = log_regex.match(line)
    if match:
        # If the line matches the regex, extract data into a dictionary
        log_data = match.groupdict()
        log_collection.append(log_data)
    else:
        print(f"Line does not match format: {line}")

# Convert to Pandas DataFrame
df = pd.DataFrame(log_collection)

# Show the DataFrame
df
# Out:
#                   timestamp   duration type  \
# 0   2024-06-28T15:32:42.672    0.00000  TFI
# 1   2024-06-28T15:32:42.680    8.07220  SEN
# 2   2024-06-28T15:32:42.726   45.15410  VDC
# 3   2024-06-28T15:33:03.763  21.03695s  APR
# 4   2024-06-28T15:33:03.763    0.07810  REC
# 5   2024-06-28T15:33:03.763    0.18260  VDC
# 6   2024-06-28T15:33:03.763    0.00000  TFI
# 7   2024-06-28T15:33:03.767    3.73560  SEN
# 8   2024-06-28T15:33:08.767   5.00071s  SEN
# 9   2024-06-28T15:33:26.251  17.48340s  RES
# 10  2024-06-28T15:33:26.254    3.18260  APR
# 11  2024-06-28T15:33:26.254    0.12820  TFI
# 12  2024-06-28T15:33:26.259    5.48120  SEN
# 13  2024-06-28T15:33:27.717   1.45763s  REM
# 14  2024-06-28T15:33:27.717    0.00000  TFI
# 15  2024-06-28T15:33:27.719    1.65430  SEN
# 16  2024-06-28T15:33:37.401   9.68267s  REC
# 17  2024-06-28T15:33:37.401    0.00000  TFI
# 18  2024-06-28T15:33:37.410    8.39830  SEN
# 19  2024-06-28T15:33:38.642   1.23219s  RES
# 20  2024-06-28T15:33:38.642    0.00000  TFI
# 21  2024-06-28T15:33:38.646    3.72120  SEN
# 22  2024-06-28T15:33:40.247   1.60108s  REM
# 23  2024-06-28T15:33:40.247    0.00000  TFI
# 24  2024-06-28T15:33:40.252    5.35940  SEN
# 25  2024-06-28T15:34:06.143  25.89064s  REC
# 26  2024-06-28T15:34:06.143    0.00000  TFI
# 27  2024-06-28T15:34:06.156   13.51320  SEN
# 28  2024-06-28T15:34:07.056  899.39230  APR
# 29  2024-06-28T15:34:07.056    0.05300  VDC
# 30  2024-06-28T15:34:11.158   4.10230s  SEN
# 31  2024-06-28T15:34:12.292   1.13422s  RES
# 32  2024-06-28T15:34:12.293    0.88390  APR
# 33  2024-06-28T15:34:12.293    0.04050  TFI
# 34  2024-06-28T15:34:12.296    2.67140  SEN
# 35  2024-06-28T15:34:13.407   1.11115s  REM
# 36  2024-06-28T15:34:13.407    0.00000  TFI
# 37  2024-06-28T15:34:13.409    1.66430  SEN
#
#                                               details
# 0      <        ><                ><                >
# 1   <LTL 0><ALB 0><OTL 0><MLB 0><PSN 0><PSG 0><FSW...
# 2                                             Bounded
# 3   Enlist [PUTRAJAYA5555     ][470M669NWA7R1X32  ...
# 4   <QID 3B9ACA01><PSN F><PSG _><TRX S=SE V=INI E=...
# 5           Select [1:1,0][470M669NWA7R1X32  ] 0 -> 0
# 6      <1       ><                ><                >
# 7   <LTL 0><ALB 0><OTL 0><MLB 0><PSN 0><PSG 0><FSW...
# 8   <LTL 0><ALB 0><OTL 0><MLB 0><PSN 0><PSG 0><FSW...
# 9   <QID 3B9ACA01><PSN F><PSG _><TRX S=OK V=EXM E=...
# 10  Select [PUTRAJAYA5555     ][470M669NWA7R1X32  ...
# 11     <1       ><SELAMAT         ><JALAN           >
# 12  <LTL 1><ALB 0><OTL 0><MLB 0><PSN 0><PSG 0><FSW...
# 13  <QID 3B9ACA01><PSN F><PSG _><TRX S=OK V=EXM E=...
# 14     <        ><                ><                >
# 15  <LTL 0><ALB 0><OTL 0><MLB 0><PSN 0><PSG 0><FSW...
# 16  <QID 3B9ACA02><PSN F><PSG _><TRX S=SE V=INI E=...
# 17     <2       ><                ><                >
# 18  <LTL 0><ALB 0><OTL 0><MLB 0><PSN 0><PSG 0><FSW...
# 19  <QID 3B9ACA02><PSN F><PSG _><TRX S=OK V=EXM E=...
# 20     <2       ><SELAMAT         ><JALAN           >
# 21  <LTL 1><ALB 0><OTL 0><MLB 0><PSN 0><PSG 0><FSW...
# 22  <QID 3B9ACA02><PSN F><PSG _><TRX S=OK V=EXM E=...
# 23     <        ><                ><                >
# 24  <LTL 0><ALB 0><OTL 0><MLB 0><PSN 0><PSG 0><FSW...
# 25  <QID 3B9ACA03><PSN F><PSG _><TRX S=SE V=INI E=...
# 26     <3       ><                ><                >
# 27  <LTL 0><ALB 0><OTL 0><MLB 0><PSN 0><PSG 0><FSW...
# 28  Enlist [PUTRAJAYA5555     ][470M669NWA7R1X33  ...
# 29          Select [2:2,0][470M669NWA7R1X33  ] 0 -> 0
# 30  <LTL 0><ALB 0><OTL 0><MLB 0><PSN 0><PSG 0><FSW...
# 31  <QID 3B9ACA03><PSN F><PSG _><TRX S=OK V=EXM E=...
# 32  Select [PUTRAJAYA5555     ][470M669NWA7R1X33  ...
# 33     <3       ><SELAMAT         ><JALAN           >
# 34  <LTL 1><ALB 0><OTL 0><MLB 0><PSN 0><PSG 0><FSW...
# 35  <QID 3B9ACA03><PSN F><PSG _><TRX S=OK V=EXM E=...
# 36     <        ><                ><                >
# 37  <LTL 0><ALB 0><OTL 0><MLB 0><PSN 0><PSG 0><FSW...

# %%
# Splitting the 'details' column by the '<>' pattern and expand into separate columns
df_details_split = df['details'].str.split(r'[<>]', expand=True)

# Display the resulting DataFrame with split 'details' columns
#df_combined = pd.concat([df, df_details_split], axis=1)
#df_combined

df_details_split
# Out:
#                                                    0             1     2   \
# 0
# 1                                                             LTL 0
# 2                                             Bounded          None  None
# 3   Enlist [PUTRAJAYA5555     ][470M669NWA7R1X32  ...             1  None
# 4                                                      QID 3B9ACA01
# 5              Select [1:1,0][470M669NWA7R1X32  ] 0 -             0  None
# 6                                                          1
# 7                                                             LTL 0
# 8                                                             LTL 0
# 9                                                      QID 3B9ACA01
# 10  Select [PUTRAJAYA5555     ][470M669NWA7R1X32  ...             0  None
# 11                                                         1
# 12                                                            LTL 1
# 13                                                     QID 3B9ACA01
# 14
# 15                                                            LTL 0
# 16                                                     QID 3B9ACA02
# 17                                                         2
# 18                                                            LTL 0
# 19                                                     QID 3B9ACA02
# 20                                                         2
# 21                                                            LTL 1
# 22                                                     QID 3B9ACA02
# 23
# 24                                                            LTL 0
# 25                                                     QID 3B9ACA03
# 26                                                         3
# 27                                                            LTL 0
# 28  Enlist [PUTRAJAYA5555     ][470M669NWA7R1X33  ...             1  None
# 29             Select [2:2,0][470M669NWA7R1X33  ] 0 -             0  None
# 30                                                            LTL 0
# 31                                                     QID 3B9ACA03
# 32  Select [PUTRAJAYA5555     ][470M669NWA7R1X33  ...             0  None
# 33                                                         3
# 34                                                            LTL 1
# 35                                                     QID 3B9ACA03
# 36
# 37                                                            LTL 0
#
#                   3     4                 5     6                    7     8   \
# 0                                                                  None  None
# 1              ALB 0                   OTL 0                      MLB 0
# 2               None  None              None  None                 None  None
# 3               None  None              None  None                 None  None
# 4              PSN F                   PSG _        TRX S=SE V=INI E=00
# 5               None  None              None  None                 None  None
# 6                                                                  None  None
# 7              ALB 0                   OTL 0                      MLB 0
# 8              ALB 0                   OTL 0                      MLB 0
# 9              PSN F                   PSG _        TRX S=OK V=EXM E=00
# 10              None  None              None  None                 None  None
# 11  SELAMAT                 JALAN                                  None  None
# 12             ALB 0                   OTL 0                      MLB 0
# 13             PSN F                   PSG _        TRX S=OK V=EXM E=00
# 14                                                                 None  None
# 15             ALB 0                   OTL 0                      MLB 0
# 16             PSN F                   PSG _        TRX S=SE V=INI E=00
# 17                                                                 None  None
# 18             ALB 0                   OTL 0                      MLB 0
# 19             PSN F                   PSG _        TRX S=OK V=EXM E=00
# 20  SELAMAT                 JALAN                                  None  None
# 21             ALB 0                   OTL 0                      MLB 0
# 22             PSN F                   PSG _        TRX S=OK V=EXM E=00
# 23                                                                 None  None
# 24             ALB 0                   OTL 0                      MLB 0
# 25             PSN F                   PSG _        TRX S=SE V=INI E=00
# 26                                                                 None  None
# 27             ALB 0                   OTL 0                      MLB 0
# 28              None  None              None  None                 None  None
# 29              None  None              None  None                 None  None
# 30             ALB 0                   OTL 0                      MLB 0
# 31             PSN F                   PSG _        TRX S=OK V=EXM E=00
# 32              None  None              None  None                 None  None
# 33  SELAMAT                 JALAN                                  None  None
# 34             ALB 0                   OTL 0                      MLB 0
# 35             PSN F                   PSG _        TRX S=OK V=EXM E=00
# 36                                                                 None  None
# 37             ALB 0                   OTL 0                      MLB 0
#
#          9   ...                   13    14                  15    16  \
# 0      None  ...                 None  None                None  None
# 1     PSN 0  ...                FSW 0                     ODR 0
# 2      None  ...                 None  None                None  None
# 3      None  ...                 None  None                None  None
# 4   TRM M66  ...  CLS O=1 D=1 F=1 A=0        TFR F=0 G=0 V=0.00
# 5      None  ...                 None  None                None  None
# 6      None  ...                 None  None                None  None
# 7     PSN 0  ...                FSW 0                     ODR 0
# 8     PSN 0  ...                FSW 0                     ODR 0
# 9   TRM M66  ...  CLS O=1 D=1 F=1 A=0        TFR F=0 G=0 V=0.00
# 10     None  ...                 None  None                None  None
# 11     None  ...                 None  None                None  None
# 12    PSN 0  ...                FSW 0                     ODR 0
# 13  TRM M66  ...  CLS O=1 D=1 F=1 A=0        TFR F=0 G=0 V=0.00
# 14     None  ...                 None  None                None  None
# 15    PSN 0  ...                FSW 0                     ODR 0
# 16  TRM M66  ...  CLS O=2 D=2 F=2 A=0        TFR F=0 G=0 V=0.00
# 17     None  ...                 None  None                None  None
# 18    PSN 0  ...                FSW 0                     ODR 0
# 19  TRM M66  ...  CLS O=2 D=2 F=2 A=0        TFR F=0 G=0 V=0.00
# 20     None  ...                 None  None                None  None
# 21    PSN 0  ...                FSW 0                     ODR 0
# 22  TRM M66  ...  CLS O=2 D=2 F=2 A=0        TFR F=0 G=0 V=0.00
# 23     None  ...                 None  None                None  None
# 24    PSN 0  ...                FSW 0                     ODR 0
# 25  TRM M66  ...  CLS O=3 D=3 F=3 A=0        TFR F=0 G=0 V=0.00
# 26     None  ...                 None  None                None  None
# 27    PSN 0  ...                FSW 0                     ODR 0
# 28     None  ...                 None  None                None  None
# 29     None  ...                 None  None                None  None
# 30    PSN 0  ...                FSW 0                     ODR 0
# 31  TRM M66  ...  CLS O=3 D=3 F=3 A=0        TFR F=0 G=0 V=0.00
# 32     None  ...                 None  None                None  None
# 33     None  ...                 None  None                None  None
# 34    PSN 0  ...                FSW 0                     ODR 0
# 35  TRM M66  ...  CLS O=3 D=3 F=3 A=0        TFR F=0 G=0 V=0.00
# 36     None  ...                 None  None                None  None
# 37    PSN 0  ...                FSW 0                     ODR 0
#
#                 17    18                      19    20     21    22
# 0             None  None                    None  None   None  None
# 1            RMP 0                         ASB 0        VCD 0
# 2             None  None                    None  None   None  None
# 3             None  None                    None  None   None  None
# 4   CID 0000000000        AID 000000000000000000         None  None
# 5             None  None                    None  None   None  None
# 6             None  None                    None  None   None  None
# 7            RMP 0                         ASB 0        VCD 1
# 8            RMP 0                         ASB 0        VCD 0
# 9   CID 0000000000        AID 000000000000000000         None  None
# 10            None  None                    None  None   None  None
# 11            None  None                    None  None   None  None
# 12           RMP 0                         ASB 0        VCD 1
# 13  CID 0000000000        AID 000000000000000000         None  None
# 14            None  None                    None  None   None  None
# 15           RMP 0                         ASB 0        VCD 0
# 16  CID 0000000000        AID 000000000000000000         None  None
# 17            None  None                    None  None   None  None
# 18           RMP 0                         ASB 0        VCD 2
# 19  CID 0000000000        AID 000000000000000000         None  None
# 20            None  None                    None  None   None  None
# 21           RMP 0                         ASB 0        VCD 2
# 22  CID 0000000000        AID 000000000000000000         None  None
# 23            None  None                    None  None   None  None
# 24           RMP 0                         ASB 0        VCD 0
# 25  CID 0000000000        AID 000000000000000000         None  None
# 26            None  None                    None  None   None  None
# 27           RMP 0                         ASB 0        VCD 3
# 28            None  None                    None  None   None  None
# 29            None  None                    None  None   None  None
# 30           RMP 0                         ASB 0        VCD 0
# 31  CID 0000000000        AID 000000000000000000         None  None
# 32            None  None                    None  None   None  None
# 33            None  None                    None  None   None  None
# 34           RMP 0                         ASB 0        VCD 3
# 35  CID 0000000000        AID 000000000000000000         None  None
# 36            None  None                    None  None   None  None
# 37           RMP 0                         ASB 0        VCD 0
#
# [38 rows x 23 columns]
